# %% [markdown]
# ### pip install ipyturtle3

# %%
import turtle

# %%
tur = turtle.Turtle()

# %%
def set_turtle():
    tur.shape('turtle')

# %%
def draw_line():
    tur.forward(100)

# %%
set_turtle()

# %%
draw_line()

# %%
tur.color('black','red')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [14], in <cell line: 1>()
# ----> 1 tur.color('black','red')
#
# File ~\anaconda3\lib\turtle.py:2217, in TPen.color(self, *args)
#    2215 elif l == 3:
#    2216     pcolor = fcolor = args
# -> 2217 pcolor = self._colorstr(pcolor)
#    2218 fcolor = self._colorstr(fcolor)
#    2219 self.pen(pencolor=pcolor, fillcolor=fcolor)
#
# AttributeError: 'str' object has no attribute '_colorstr'

# %%
tur.backward(50)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [15], in <cell line: 1>()
# ----> 1 tur.backward(50)
#
# TypeError: back() missing 1 required positional argument: 'distance'

# %%
tur.left(90)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [16], in <cell line: 1>()
# ----> 1 tur.left(90)
#
# TypeError: left() missing 1 required positional argument: 'angle'

# %%
tur.right(90)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [17], in <cell line: 1>()
# ----> 1 tur.right(90)
#
# TypeError: right() missing 1 required positional argument: 'angle'

# %%
tur.hideturtle()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [18], in <cell line: 1>()
# ----> 1 tur.hideturtle()
#
# TypeError: hideturtle() missing 1 required positional argument: 'self'

# %%
tur.showturtle()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [19], in <cell line: 1>()
# ----> 1 tur.showturtle()
#
# TypeError: showturtle() missing 1 required positional argument: 'self'

# %%
tur.circle(40)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [20], in <cell line: 1>()
# ----> 1 tur.circle(40)
#
# TypeError: circle() missing 1 required positional argument: 'radius'

# %%
tur.clear()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [21], in <cell line: 1>()
# ----> 1 tur.clear()
#
# TypeError: clear() missing 1 required positional argument: 'self'

# %%
def draw_square():
    #SQUARE
    #side = int(input("Length of side: "))
    side = 50
    for i in range(4):
       tur.forward(side)
       tur.left(90)

def draw_rectange():
    #RECTANGLE
    tur.clear()
    #side_a = int(input("Length of side a: "))
    #side_b = int(input("Length of side b: "))
    side_a = 30
    side_b = 40
    tur.forward(side_a)
    tur.left(90)
    tur.forward(side_b)
    tur.left(90)
    tur.forward(side_a)
    tur.left(90)
    tur.forward(side_b)
    tur.left(90)
    
def draw_circle():
    #CIRCLE
    tur.clear()
    #radius = int(input("Radius of circle: "))
    radius = 40
    tur.circle(radius)
    
    
def draw_hexagon():
    #HEXAGON
    tur.clear()
    side = 50
    for i in range(6):
       tur.forward(side)
       tur.left(300)

def draw_triangle():  
    #TRIANGLE
    tur.clear()
    side = 50
    for i in range(3):
        tur.forward(side)
        tur.left(360/3)
        
def draw_david():
    tur.pen(pencolor="darkblue", fillcolor="blue", pensize=8, speed=3)
    tur.clear()
    show_turtle()
    side = 50
    for step in range(6):
        tur.begin_fill()
        for i in range(3):
            tur.forward(side)
            tur.left(360/3)
        tur.end_fill()
        tur.forward(side)
        #t.right(60)
        tur.left(300)
    hide_turtle()
    tur.pen(pencolor="black", pensize=1)
    
    
def clear():
    tur.clear()
    
 
def show_turtle():
    tur.showturtle()
    pass

def hide_turtle():
    tur.hideturtle()
    pass

def many_turtles():
    tur1 = turtle.Turtle()
    tur1.up()
    tur1.setpos(-100, 50)
    tur1.down()
    tur1.circle(50)


    tur2 = turtle.Turtle()
    tur2.up()
    tur2.setpos(50, 50)
    tur2.down()
    tur2.circle(50)


    tur3 = turtle.Turtle()
    tur3.up()
    tur3.setpos(50, -100)
    tur3.down()
    tur3.circle(50)


    tur4 = turtle.Turtle()
    tur4.up()
    tur4.setpos(-100, -100)
    tur4.down()
    tur4.circle(50)


    tur1.clear()
    tur3.clear()
    #turtle.done()
    

def exit_turtle():
    tur.bye()

# %%
try:
    draw_david()
except Exception as ex:
    print(ex)
# Out:
# pen() missing 1 required positional argument: 'self'

# %%
draw_rectange()

# %%
draw_square()

# %%
draw_circle()

# %%
draw_hexagon()

# %%
draw_triangle()

# %%
clear()

# %%
show_turtle()

# %%
hide_turtle()

# %%
many_turtles()

# %%
for step in range(6):
    tur.begin_fill()
    for i in range(3):
        tur.forward(50)
        tur.left(360/3)
    tur.end_fill()
    tur.forward(50)
    tur.right(60)

# %%
def spiral_triangle():
    n = 8
    clear()
    tur.setpos(50, 50)
    tur.pen(pencolor="black", fillcolor="orange", pensize=5, speed=3)
    #tur.clear()
    for i in range(n * 6): 
        tur.forward(i * 8) 
        #tur.right(120)
        tur.left(120)

# %%
spiral_triangle()

# %%
tur.left(900)

# %%
import math.random

# %%
def fractal(size=360 , speed=6):
    tur.speed(speed)

    tur.getscreen().bgcolor("black")
    tur.color("cyan")

    tur.penup()

    tur.goto((-200, 50))


    tur.pendown()


    def star(turtle, size):
        if size <= 1:
            return
        else:
            for i in range(5):


                turtle.forward(size)
                star(turtle, size/3)

                turtle.left(216)


    star(tur, size)
    turtle.done()

# %%
fractal(400,20)

# %%
exit_turtle()

# %%
tur.pen(pencolor="purple", fillcolor="orange", pensize=10, speed=9)
tur.begin_fill()
tur.circle(90)
tur.end_fill()

# %%
n=10
while n <= 120:
    tur.circle(n)
    n = n+10

# %%
from turtle import *
import turtle
  
  
speed('fastest')
  

right(-90)
  

angle = 30
  

def yaxis(size, lvl):   
  
    if lvl > 0:
        colormode(255)
          
       
        pencolor(0, 255//lvl, 0)
          
        forward(size)
  
        right(angle)
 
        yaxis(0.8 * size, lvl-1)
          
        pencolor(0, 255//lvl, 0)
          
        lt( 2 * angle )
  
        yaxis(0.8 * size, lvl-1)
          
        pencolor(0, 255//lvl, 0)
          
        right(angle)
        forward(-size)
           
yaxis(90, 7)
turtle.done()
